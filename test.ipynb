# %%
geoJson = {
    "type": "Feature",
    "properties": {},
    "geometry": {
        "type": "Polygon",
        "coordinates": [
            [
                [
                    89.493119,
                    23.59797
                ],
                [
                    89.697066,
                    23.67094
                ],
                [
                    89.903689,
                    23.502293
                ],
                [
                    89.638717,
                    23.357386
                ],
                [
                    89.516527,
                    23.497885
                ],
                [
                    89.493119,
                    23.59797
                ]
            ]
        ]
    }
}

# %%
from models.anlyzers.uhi_hotspots import run

# %%
desc_json = run(session_id="test_uhi_001", geoJson=geoJson)
# Out:
# Initializing Earth Engine…2
# BBOX from GeoJSON: [89.493119, 23.357385999999977, 89.903689, 23.670940000000027]
# Started UHI hotspot analysis… Session: test_uhi_001
# AOI: given | Window: 2025-08-26 → 2025-10-25
# Day & night LST Means...
# Making sample grid for clustering...
# for f in feats
# Done... got 887 valid samples.
#  z-scores & pick hotspots...
#  Cluster & envelopes...
#  Starting zip(hotspots, clusters) loop
#  done
#  Union per cluster & areas...
#  Top-3 by area...
#  Ancillary datasets…
# f:\nasa sace app\venv\Lib\site-packages\ee\deprecation.py:209: DeprecationWarning:
#
# Attention required for COPERNICUS/S2_SR! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR
#
#   warnings.warn(warning, category=DeprecationWarning)
#  ERA5 air temp & dewpoint…
#  Season windows & pre-monsoon, monsoon, post-monsoon LST means…
# ...

# %%
desc_json
# Out:
# {'meta': {'center': [23.514163000000003, 89.698404],
#   'zoom': 12,
#   'tiles': 'cartodbpositron'},
#  'layers': {'clusters': {'type': 'FeatureCollection',
#    'features': [{'type': 'Feature',
#      'properties': {'cid': 1,
#       'rank': 1,
#       'name': 'Hot zone #1 (cluster 1)',
#       'style': {'color': '#2563eb',
#        'weight': 3,
#        'fillColor': '#2563eb',
#        'fillOpacity': 0.1},
#       'tooltip': 'Hot zone #1 (cluster 1)',
# ...
