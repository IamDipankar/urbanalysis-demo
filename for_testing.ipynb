# %%
from models.anlyzers import router
from models.anlyzers import aq_hotspots, uhi_hotspots, green_access_ndvi
from memory_profiler import profile

# %%
ee_geometry, aoi_bbox = router.get_polygon_and_bbox("Mymensingh", "Haluaghat")
